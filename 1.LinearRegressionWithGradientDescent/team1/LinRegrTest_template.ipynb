# %%
! pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\giuseppe.manai\appdata\roaming\python\python39\site-packages (from -r requirements.txt (line 1)) (1.24.2)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (3.5.2)
# Requirement already satisfied: jupyter_contrib_nbextensions in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->-r requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: ipython_genutils in c:\programdata\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: jupyter_contrib_core>=0.3.3 in c:\programdata\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.4.2)
# Requirement already satisfied: jupyter_core in c:\programdata\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (4.11.1)
# Requirement already satisfied: jupyter_highlight_selected_word>=0.1.1 in c:\programdata\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: jupyter_nbextensions_configurator>=0.4.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.6.1)
# Requirement already satisfied: nbconvert>=6.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (6.4.4)
# Requirement already satisfied: notebook>=6.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (6.4.12)
# Requirement already satisfied: tornado in c:\programdata\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (6.1)
# Requirement already satisfied: traitlets>=4.1 in c:\programdata\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: lxml in c:\programdata\anaconda3\lib\site-packages (from jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (4.9.1)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from jupyter_contrib_core>=0.3.3->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (63.4.1)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from jupyter_nbextensions_configurator>=0.4.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (6.0)
# Requirement already satisfied: jupyterlab-pygments in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.4)
# Requirement already satisfied: pygments>=2.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (2.11.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.5.13)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (4.11.1)
# Requirement already satisfied: defusedxml in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: bleach in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (4.1.0)
# Requirement already satisfied: jinja2>=2.4 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (2.11.3)
# Requirement already satisfied: testpath in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: nbformat>=4.4 in c:\programdata\anaconda3\lib\site-packages (from nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (5.5.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (7.3.4)
# Requirement already satisfied: ipykernel in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (6.15.2)
# Requirement already satisfied: argon2-cffi in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (21.3.0)
# Requirement already satisfied: pyzmq>=17 in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (23.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (1.5.5)
# Requirement already satisfied: prometheus-client in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.14.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\programdata\anaconda3\lib\site-packages (from notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.13.1)
# Requirement already satisfied: pywin32>=1.0 in c:\programdata\anaconda3\lib\site-packages (from jupyter_core->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (302)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: fastjsonschema in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\programdata\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (4.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (2.3.1)
# Requirement already satisfied: webencodings in c:\programdata\anaconda3\lib\site-packages (from bleach->nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.5.1)
# Requirement already satisfied: psutil in c:\programdata\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: ipython>=7.23.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (7.31.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\programdata\anaconda3\lib\site-packages (from ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.1.6)
# Requirement already satisfied: backcall in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.4.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (3.0.20)
# Requirement already satisfied: pickleshare in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: decorator in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\programdata\anaconda3\lib\site-packages (from ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\programdata\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.18.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (1.15.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\programdata\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.8.3)
# Requirement already satisfied: wcwidth in c:\programdata\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->notebook>=6.0->jupyter_contrib_nbextensions->-r requirements.txt (line 3)) (0.2.5)

# %%
import numpy as np 
import random
import matplotlib.pyplot as plt
import LinRegrGD_template as LR

# %%
# set the random seed
np.random.seed(123)

# set the parameters for testing
offset_true = 1
slope_true = 3

# generate the data
sample_size = 300
data = np.linspace(0, 2, sample_size)
noise = np.random.normal(0, 1, size=sample_size)
y_noise = offset_true + slope_true * data + noise
y_true = offset_true + slope_true * data

X = np.ones((sample_size, 2))
X[:, 1] = data
X.shape
# Out:
# (300, 2)

# %%
# apply gradient descent to get the parameters and cost for each iteration
starting_params = np.array([0, 0])
learning_rate = 0.01
num_iterations = 100
param, costs = LR.gradient_descent(X, y_noise, starting_params, learning_rate, num_iterations)

# plot the cost function
plt.plot(list(range(num_iterations)), costs)
plt.title("Cost over {} iterations".format(num_iterations))
plt.xlabel("Iteration number")
plt.ylabel("Cost")
plt.show()

# %%
# plot the regression line obtained from gradient descent
LR.plot_regression_line(data, y_noise, param)
plt.plot(data, y_true, color='g', label="True line: 1 + 3x")
plt.title("Predicted vs. true regression line")
plt.xlabel("x")
plt.ylabel("y")
plt.legend()
plt.show()
