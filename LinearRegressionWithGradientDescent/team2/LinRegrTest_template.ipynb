# %% [markdown]
# ## Team 2
#
# Ahmed Fedi Lassoued
#
# Lim Shan En Daniel
#
# Tristan Koh Ly Wey
#
# Vasu Namdeo
#
# Zen Alexander Goh Wei Han
#
# Naman Vishal Kedia

# %%
import numpy as np
from functions import *

# %%
X = np.arange(0, 50)

# Generate random noise with mean 0 and standard deviation 10
np.random.seed(109101)
noise = np.random.normal(0, 10, 50) 

# Generate y values as x plus some random noise
y = X + noise

# Initialise params: (weight, bias)
params = (0.1, 0.01)

# Initialise hyperparameters
learning_rate = 0.0001
num_iterations = 2000

# Estimating weight and bias using gradient descent
trained_params = gradient_descent(X, y, params, learning_rate, num_iterations)

params = (trained_params["fitted_weight"], trained_params["fitted_bias"])
weights = trained_params["weights"]
costs = trained_params["costs"]

# %%
plot_cost_function(weights, costs)

# %%
plot_regression_line(X, y, params)
