# %%
# Importing libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Importing functions from `LinRegrGD_template.ipynb`
# %run LinRegrGD_template.ipynb
import LinRegrGD_template as LR

# %%
# Load or generate the data and make sure is somehow showing a linear behaviour. 
# Since we loaded existing data, we do not set a random seed.
df = sns.load_dataset('car_crashes')
X = df['alcohol']
y = df['total']
sns.scatterplot(x=X,y=y) # We check that the data is linear
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='total'>

# %%
# Converting X1 from series to a dataframe
X = X.to_frame()

# %%
# Add a column of ones to X
X.insert(0, 'X0', np.ones(len(X)))
X.head()
# Out:
#     X0  alcohol
# 0  1.0    5.640
# 1  1.0    4.525
# 2  1.0    5.208
# 3  1.0    5.824
# 4  1.0    3.360

# %%
# Initialize the parameters and setting the hyperparameters
param = [1, 2.5]
learning_rate = 0.001
num_iterations = 200

# %%
# Run gradient descent
params = gradient_descent(X, y, param, learning_rate, num_iterations)[0]
params
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /usr/local/lib/python3.8/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/lib/python3.8/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 18
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Plot the cost function
cost_values = gradient_descent(X, y, param, learning_rate, num_iterations)[1]

plt.plot(range(len(cost_values)), cost_values)
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.show()

# %%
# Plot the regression line
plot_regression_line(X, y, param)
# Out:
# ([<matplotlib.lines.Line2D at 0x1151d00a0>],
#  [<matplotlib.lines.Line2D at 0x1151d0490>])
